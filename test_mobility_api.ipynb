# %% [markdown]
# Test Mobility API

# %%
# Importieren der requests-Bibliothek
import requests
from pprint import pprint

# %%
# URL der API
url = "https://api.electricitymap.org/v3/zones"

# Ersetzen Sie 'myapitoken' mit Ihrem persönlichen API-Token
headers = {
    'auth-token': 'ZRwCcBovopsQf3d6n47DnhztH9YLCUE1'
}

# Durchführen des GET-Request
response = requests.get(url, headers=headers)

# Überprüfung des Status-Codes der Antwort
if response.status_code == 200:
    # Wenn die Antwort erfolgreich war, Umwandlung der Antwort in JSON
    data = response.json()
    print(data)
else:
    print("Fehler beim API-Call:", response.status_code)
# Out:
# Fehler beim API-Call: 401

# %%
import requests
from pprint import pprint

# URL der API
url = "https://api.electricitymap.org/v3/power-breakdown/latest?lat=48.8566&lon=2.3522"

# Ersetzen Sie 'Ihr-API-Token' mit Ihrem tatsächlichen API-Token
headers = {
    'auth-token': 'z3HdNiMkCaMeEF7jkIXzuGbqMHiEiHai'
}

# Durchführen des GET-Requests mit dem benutzerdefinierten Header
response = requests.get(url, headers=headers)

# Überprüfung des Status-Codes der Antwort
if response.status_code == 200:
    # Wenn die Antwort erfolgreich war, Umwandlung der Antwort in JSON
    data = response.json()
    pprint(data)
else:
    # Gibt den Status-Code und eventuelle Fehlernachrichten aus
    print("Fehler beim API-Call:", response.status_code)
    pprint(response.json())
# Out:
# Fehler beim API-Call: 401
# {'error': 'Invalid auth-token'}

# %%
# URL der API
url = "https://api.electricitymap.org/v3/zones"

# Durchführen des GET-Request
response = requests.get(url)

# Überprüfung des Status-Codes der Antwort
if response.status_code == 200:
    # Wenn die Antwort erfolgreich war, Umwandlung der Antwort in JSON
    data = response.json()
    pprint(data)
else:
    print("Fehler beim API-Call:", response.status_code)
# Out:
# {'AD': {'zoneName': 'Andorra'},
#  'AE': {'zoneName': 'United Arab Emirates'},
#  'AF': {'zoneName': 'Afghanistan'},
#  'AG': {'zoneName': 'Antigua and Barbuda'},
#  'AL': {'zoneName': 'Albania'},
#  'AM': {'zoneName': 'Armenia'},
#  'AO': {'zoneName': 'Angola'},
#  'AR': {'zoneName': 'Argentina'},
#  'AT': {'zoneName': 'Austria'},
#  'AU': {'zoneName': 'Australia'},
#  'AU-LH': {'countryName': 'Australia', 'zoneName': 'Lord Howe Island'},
#  'AU-NSW': {'countryName': 'Australia', 'zoneName': 'New South Wales'},
#  'AU-NT': {'countryName': 'Australia', 'zoneName': 'Northern Territory'},
#  'AU-QLD': {'countryName': 'Australia', 'zoneName': 'Queensland'},
#  'AU-SA': {'countryName': 'Australia', 'zoneName': 'South Australia'},
#  'AU-TAS': {'countryName': 'Australia', 'zoneName': 'Tasmania'},
#  'AU-TAS-CBI': {'countryName': 'Australia', 'zoneName': 'Cape Barren Island'},
#  'AU-TAS-FI': {'countryName': 'Australia', 'zoneName': 'Flinders Island'},
# ...

# %% [markdown]
# test 3

# %% [markdown]
# test3
